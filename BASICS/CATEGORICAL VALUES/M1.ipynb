# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/home/yadhu/MEGA/ML TUTORIALS/BASICS/CATEGORICAL VALUES/sample.csv")

# %%
dataset.head()
# Out:
#      name  gender  mark
# 0  adarsh    male    50
# 1   henry    male    45
# 2     joe    male    42
# 3     adi    male    35
# 4    ammu  female    48

# %%
dataset.isna().sum()
# Out:
# name      0
# gender    0
# mark      0
# dtype: int64

# %%
dum = pd.get_dummies(dataset['gender'])
dum
# Out:
#    female  male
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       1     0
# 5       1     0
# 6       1     0
# 7       1     0

# %%
dataset = pd.concat([dataset,dum],axis=1).reindex(dataset.index)
dataset
# Out:
#      name  gender  mark  female  male
# 0  adarsh    male    50       0     1
# 1   henry    male    45       0     1
# 2     joe    male    42       0     1
# 3     adi    male    35       0     1
# 4    ammu  female    48       1     0
# 5    devi  female    50       1     0
# 6    sita  female    24       1     0
# 7  anjana  female    19       1     0

# %%
dataset.drop('gender',axis=1,inplace=True)

# %%
dataset
# Out:
#      name  mark  female  male
# 0  adarsh    50       0     1
# 1   henry    45       0     1
# 2     joe    42       0     1
# 3     adi    35       0     1
# 4    ammu    48       1     0
# 5    devi    50       1     0
# 6    sita    24       1     0
# 7  anjana    19       1     0
