# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/home/yadhu/MEGA/ML TUTORIALS/LINEAR REGRESSION/Salary_dataset.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
x = dataset[['YearsExperience']]
y = dataset.iloc[:,-1].values

# %%
plt.scatter(x, y)
plt.xlabel('Salary')
plt.ylabel('Years Experiencie')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.4,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, y_test_pred, color='red', linewidth=3)
plt.xlabel('Salary')
plt.ylabel('Years Experiencie')
plt.show()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [9407.35651165]
# 25899.2602427921

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse_train = mean_squared_error(y_train,y_train_pred)
mse_test = mean_squared_error(y_test,y_test_pred)
print("MSE of train : ",mse_train)
print("MSE of test : ",mse_test)
r2_train = r2_score(y_train,y_train_pred)
r2_test = r2_score(y_test,y_test_pred)
print("r square of train : ",r2_train)
print("r square of test : ",r2_test)
# Out:
# MSE of train :  36440326.430921294
# MSE of test :  25234929.186605293
# r square of train :  0.9438034942328755
# r square of test :  0.9679117063698978

# %% [markdown]
# # Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
adj_r2_train = 1-((1-r2_train)*(len(y)-1)/(len(y)-x.shape[1]-1))
adj_r2_test = 1-((1-r2_test)*(len(y)-1)/(len(y)-x.shape[1]-1))

# %%
print("adjusted r2 of train : ",adj_r2_train)
print("adjusted r2 of test : ",adj_r2_test)
# Out:
# adjusted r2 of train :  0.9417964761697639
# adjusted r2 of test :  0.9667656958831083
